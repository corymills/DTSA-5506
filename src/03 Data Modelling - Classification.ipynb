# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
import pickle
import numpy as np

# %%
df = pd.read_pickle("../data/processed.pkl")
categorical_columns = df.select_dtypes(include=['category']).columns

# %%
with open("../data/data_element_details.pkl", "rb") as file:
    data_element_details = pickle.load(file)

# %%
section_dict = {
    "Chronic Health Conditions": [], 
    "Social Determinants and Health Equity": [],
    "Disability": [],
    "Sexual Orientation and Gender Identity (SOGI)": []
}

keep_cols = []
for value in data_element_details.values():
    column_name = f"{value['Label']} ({value['SAS Variable Name']})"
    if value['Section Name'] in section_dict.keys() and column_name in df.columns:
        for key, valid_values in value['Valid Values'].items():
            v = f"{column_name}:{key} - {valid_values['Value Label']}"
            section_dict[value['Section Name']].append( frozenset({v}) )
        keep_cols.append(column_name)
df_a = df[keep_cols]
df_a = df_a[df_a['(Ever told) you had a depressive disorder (ADDEPEV3)'].isin(['1 - Yes', '2 - No'])]

# %%
from sklearn.tree import DecisionTreeClassifier , export_text, _tree
from sklearn import tree
import matplotlib.pyplot as plt

X = df_a.drop('(Ever told) you had a depressive disorder (ADDEPEV3)', axis=1)
X = pd.get_dummies(X)
y = df_a['(Ever told) you had a depressive disorder (ADDEPEV3)']

# Create decision tree classifier object
clf = DecisionTreeClassifier(random_state=0, max_depth=10)

# Train decision tree classifier
model = clf.fit(X, y)

decision_rules = export_text(clf, feature_names=X.columns)
print(decision_rules)
# Out:
# |--- Difficulty Concentrating or Remembering (DECIDE)_1 - Yes <= 0.50
# |   |--- How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.50
# |   |   |--- Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.50
# |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.50
# |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.50
# |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes <= 0.50
# |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Concentrating or Remembering (DECIDE)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Difficulty Concentrating or Remembering (DECIDE)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_7 - Dont know / Not sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_7 - Dont know / Not sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes >  0.50
# |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always >  0.50
# |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied <= 0.50
# |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_7 - Dont know/Not sure <= 0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_7 - Dont know/Not sure >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied >  0.50
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_7 - Dont know/Not sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_7 - Dont know/Not sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Dressing or Bathing (DIFFDRES)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Dressing or Bathing (DIFFDRES)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had)  melanoma or any other types of cancer? (CHCOCNC1)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had)  melanoma or any other types of cancer? (CHCOCNC1)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had)  melanoma or any other types of cancer? (CHCOCNC1)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had)  melanoma or any other types of cancer? (CHCOCNC1)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually >  0.50
# |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_2 - No <= 0.50
# |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |--- Difficulty Concentrating or Remembering (DECIDE)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Difficulty Concentrating or Remembering (DECIDE)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied <= 0.50
# |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |--- Do you consider yourself to be transgender? (TRNSGNDR)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Do you consider yourself to be transgender? (TRNSGNDR)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied >  0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_2 - No >  0.50
# |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_4 - No, pre-diabetes or borderline diabetesGo to Section 08.01 AGE <= 0.50
# |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_1 - Gay <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_1 - Gay >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_4 - No, pre-diabetes or borderline diabetesGo to Section 08.01 AGE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_2 - Yes, but female told only during pregnancyGo to Section 08.01 AGE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_2 - Yes, but female told only during pregnancyGo to Section 08.01 AGE >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_7 - Dont know/Not sure <= 0.50
# |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_7 - Dont know/Not sure >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |--- Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 >  0.50
# |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes <= 0.50
# |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_2 - Usually <= 0.50
# |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_1 - Always >  0.50
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Have you lost employment or had hours reduced? (SDHEMPLY)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Have you lost employment or had hours reduced? (SDHEMPLY)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_2 - Usually >  0.50
# |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_2 - Straight, that is, not gay >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_4 - Something else <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Have you lost employment or had hours reduced? (SDHEMPLY)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Have you lost employment or had hours reduced? (SDHEMPLY)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_4 - Something else >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely >  0.50
# |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_3 - Dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_1 - Gay <= 0.50
# |   |   |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Do you consider yourself to be transgender? (TRNSGNDR)_4 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Do you consider yourself to be transgender? (TRNSGNDR)_4 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_1 - Gay >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |--- How often do you feel socially isolated from others? (SDHISOLT)_3 - Sometimes >  0.50
# |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.50
# |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_BLANK - Not asked or Missing <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often have you felt this kind of stress? (SDHSTRE1)_7 - Dont know/Not Sure <= 0.50
# ...
# |   |   |   |   |   |   |   |   |   |--- Do you consider yourself to be transgender? (TRNSGNDR)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Were you not able to pay your bills? (SDHBILLS)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_1 - Always <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_1 - Always >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- (Ever told) (you had)  melanoma or any other types of cancer? (CHCOCNC1)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_7 - I don´t know the answer <= 0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_7 - I don´t know the answer >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Sexual orientation (SOFEMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied <= 0.50
# |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Told Had Arthritis (HAVARTH4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied >  0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_2 - Usually >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes >  0.50
# |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_1 - Yes <= 0.50
# |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Ever Diagnosed with Angina or Coronary Heart Disease (CVDCRHD4)_2 - No >  0.50
# |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_5 - Never >  0.50
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_2 - Satisfied >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Ever told you have kidney disease? (CHCKDNY2)_1 - Yes >  0.50
# |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE >  0.50
# |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |--- Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing >  0.50
# |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.50
# |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.50
# |   |   |   |   |   |   |--- Ever Diagnosed with a Stroke (CVDSTRK3)_7 - Dont know/Not sure <= 0.50
# |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Are you deaf or do you have serious difficulty hearing? (DEAF)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Ever Diagnosed with a Stroke (CVDSTRK3)_7 - Dont know/Not sure >  0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_1 - Very satisfied >  0.50
# |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_9 - Refused <= 0.50
# |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_3 - Bisexual <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_3 - Bisexual >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Difficulty Walking or Climbing Stairs (DIFFWALK)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |--- Were you not able to pay utility bills or threatened to lose service? (SDHUTILS)_9 - Refused >  0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |--- Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes >  0.50
# |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.50
# |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.50
# |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_7 - Dont know/Not Sure <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |   |--- Ever Diagnosed with Heart Attack (CVDINFR4)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Blind or Difficulty seeing (BLIND)_7 - Dont know/Not Sure >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Satisfaction with life (LSATISFY)_4 - Very dissatisfied >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |--- Ever Diagnosed with a Stroke (CVDSTRK3)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |--- Has a lack of reliable transportation kept you from appointments, meetings, work, or getting things needed (SDHTRNSP)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- Ever Diagnosed with a Stroke (CVDSTRK3)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |--- Difficulty Doing Errands Alone (DIFFALON)_2 - No >  0.50
# |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_4 - Something else <= 0.50
# |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely <= 0.50
# |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE <= 0.50
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- How often get emotional support needed (EMTSUPRT)_3 - Sometimes >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- (Ever told) you had diabetes (DIABETE4)_3 - NoGo to Section 08.01 AGE >  0.50
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |--- How often did the food that you bought not last, and you didnt have money to get more? (SDHFOOD1)_4 - Rarely >  0.50
# |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes <= 0.50
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- During the past 12 months have you received food stamps (FOODSTMP)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |   |   |--- Still Have Asthma (ASTHNOW)_1 - Yes >  0.50
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_2 - No <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2 - No
# |   |   |   |   |   |   |   |   |   |--- (Ever told) (you had) skin cancer that is not melanoma? (CHCSCNC1)_2 - No >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1 - Yes
# |   |   |   |   |   |   |--- Sexual orientation (SOMALE)_4 - Something else >  0.50
# |   |   |   |   |   |   |   |--- class: 1 - Yes

# %%
def get_rules(tree, feature_names, class_names, target_label, min_samples=1):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # calculate probabilities for each path
    probabilities = []
    for path in paths:
        classes = path[-1][0][0]
        l = np.argmax(classes)
        prob = np.round(100.0*classes[l]/np.sum(classes), 2)
        samples = path[-1][1]
        if samples >= min_samples:
            probabilities.append((prob, path))
    
    # sort by probabilities in descending order
    probabilities.sort(reverse=True)
    paths = [p[1] for p in probabilities]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "
        if class_names is None:
            rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        rule += f" | based on {path[-1][1]:,} samples"
        if class_names[l] == target_label:
            rules += [rule]
        
    return rules

# %%
y.drop_duplicates()
# Out:
# 0      2 - No
# 20    1 - Yes
# Name: (Ever told) you had a depressive disorder (ADDEPEV3), dtype: category
# Categories (5, object): ['1 - Yes', '2 - No', '7 - Dont know/Not sure', '9 - Refused', 'BLANK - Not asked or Missing']

# %%
rules = get_rules(clf, X.columns, ['1 - Yes', '2 - No', '7 - Dont know/Not sure', '9 - Refused', 'BLANK - Not asked or Missing'], "1 - Yes", 500)
for r in rules:
    print(r)
# Out:
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Still Have Asthma (ASTHNOW)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually > 0.5) and (Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.5) and (Blind or Difficulty seeing (BLIND)_2 - No > 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_2 - Usually <= 0.5) then class: 1 - Yes (proba: 82.79%) | based on 639 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Still Have Asthma (ASTHNOW)_BLANK - Not asked or Missing <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (Do you consider yourself to be transgender? (TRNSGNDR)_7 - Dont know/Not Sure <= 0.5) and (Satisfaction with life (LSATISFY)_1 - Very satisfied <= 0.5) then class: 1 - Yes (proba: 78.91%) | based on 2,542 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.5) and (Told Had Arthritis (HAVARTH4)_2 - No <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_9 - Refused <= 0.5) then class: 1 - Yes (proba: 77.71%) | based on 1,682 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (Still Have Asthma (ASTHNOW)_1 - Yes > 0.5) and (Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) then class: 1 - Yes (proba: 67.6%) | based on 1,543 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Still Have Asthma (ASTHNOW)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.5) and (Are you deaf or do you have serious difficulty hearing? (DEAF)_1 - Yes <= 0.5) then class: 1 - Yes (proba: 66.81%) | based on 4,438 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (Sexual orientation (SOFEMALE)_2 - Straight, that is, not gay > 0.5) and (During the past 12 months have you received food stamps (FOODSTMP)_1 - Yes <= 0.5) and (Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_2 - No > 0.5) then class: 1 - Yes (proba: 65.46%) | based on 964 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually > 0.5) and (Told Had Arthritis (HAVARTH4)_2 - No <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_4 - Rarely <= 0.5) and (Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.5) and (Difficulty Concentrating or Remembering (DECIDE)_2 - No > 0.5) and (Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.5) then class: 1 - Yes (proba: 65.23%) | based on 558 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes <= 0.5) and (Told Had Arthritis (HAVARTH4)_2 - No > 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (How often get emotional support needed (EMTSUPRT)_5 - Never <= 0.5) then class: 1 - Yes (proba: 64.97%) | based on 2,512 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes > 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (Told Had Arthritis (HAVARTH4)_1 - Yes > 0.5) and (During the past 12 months have you received food stamps (FOODSTMP)_2 - No > 0.5) then class: 1 - Yes (proba: 60.07%) | based on 1,345 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Still Have Asthma (ASTHNOW)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (Sexual orientation (SOFEMALE)_3 - Bisexual <= 0.5) and (Are you deaf or do you have serious difficulty hearing? (DEAF)_1 - Yes > 0.5) then class: 1 - Yes (proba: 59.42%) | based on 1,210 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (Still Have Asthma (ASTHNOW)_1 - Yes <= 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (Satisfaction with life (LSATISFY)_4 - Very dissatisfied <= 0.5) then class: 1 - Yes (proba: 57.72%) | based on 1,147 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_BLANK - Not asked or Missing > 0.5) and (Sexual orientation (SOMALE)_2 - Straight, that is, not gay <= 0.5) and (Told Had Arthritis (HAVARTH4)_1 - Yes > 0.5) and (Ever told you had C.O.P.D. emphysema or chronic bronchitis? (CHCCOPD3)_1 - Yes <= 0.5) and (Are you deaf or do you have serious difficulty hearing? (DEAF)_2 - No > 0.5) then class: 1 - Yes (proba: 56.83%) | based on 2,175 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_2 - No > 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_4 - Rarely <= 0.5) and (Sexual orientation (SOFEMALE)_BLANK - Not asked or Missing > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (Still Have Asthma (ASTHNOW)_1 - Yes > 0.5) and (Sexual orientation (SOMALE)_2 - Straight, that is, not gay > 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) then class: 1 - Yes (proba: 53.48%) | based on 503 samples
# if (Difficulty Concentrating or Remembering (DECIDE)_1 - Yes <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_5 - Never <= 0.5) and (Ever Told Had Asthma (ASTHMA3)_2 - NoGo to Section 07.06 CHCSCNC1 <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_2 - Usually <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_1 - Always <= 0.5) and (Difficulty Doing Errands Alone (DIFFALON)_1 - Yes > 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_5 - Never <= 0.5) and (How often have you felt this kind of stress? (SDHSTRE1)_3 - Sometimes > 0.5) and (How often do you feel socially isolated from others? (SDHISOLT)_7 - Dont know/Not Sure <= 0.5) and (Ever told you have kidney disease? (CHCKDNY2)_2 - No > 0.5) then class: 1 - Yes (proba: 52.27%) | based on 507 samples
