# %% [markdown]
# Imports

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Read Codebook

# %%
with open("../data/USCODE22_LLCP_102523.HTML", "r", encoding='latin1') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, "html.parser")

tables = soup.find_all("table", class_="table", attrs={"summary": "Procedure Report: Report"})

data_element_details = {}
for table in tables:
    data_element_detail = {}
    values = {}
    for i, row in enumerate(table.find_all("tr")):
        cells = [cell.get_text(strip=True, separator='\n').replace('\xa0', ' ') for cell in row.find_all(["td"])]
        if i == 0:
            matches = re.findall(r'(.*?):\s*([^\n]*)', cells[0])
            for match in matches:
                data_element_detail[match[0]] = match[1]
            if "SAS Variable Name" not in data_element_detail:
                break
        if i >= 2:
            notes_index = cells[1].find("\nNotes:")
            if notes_index != -1:
                value_label = cells[1][:notes_index]
            else:
                value_label = cells[1]
            values[cells[0]] = {"Value Label": value_label, "Frequency": cells[2], "Percentage": cells[3], "Weighted Percentage": cells[4]}
    if "SAS Variable Name" in data_element_detail:
        data_element_detail['Valid Values'] = values
        data_element_details[data_element_detail["SAS Variable Name"]] = data_element_detail

# %% [markdown]
# Output as csv for manual labelling.  NOTE manual labelling step: labelling each field as either a health outcome or not.

# %%
pd.DataFrame.from_dict(data_element_details, orient="index").to_csv("../data/fields.csv")

# %% [markdown]
# Read fixed width file data positions from html

# %%
url = '../data/CDC - BRFSS 2022 Combined Landline and Telephone Multiple Data.html'
tables = pd.read_html(url)
df_cols = tables[0]
column_names = df_cols['Variable Name']
start_positions = df_cols['Starting Column']
widths = df_cols['Field Length']
colspecs = list(zip(start_positions - 1, start_positions - 1 + widths))

# %% [markdown]
# Load file using fixed width positions extracted above

# %%
df = pd.read_fwf('../data/LLCP2022.ASC', colspecs=colspecs, header=None, names=column_names)

# %% [markdown]
# For each row, count the number and calculate the percentage of blank answers

# %%
num_cols = len(df.columns)
df['non_blank_count'] = df.isnull().sum(axis=1)
df['non_blank_perc'] = df['non_blank_count'] / (num_cols - 9)

# %% [markdown]
# Fill NAs

# %%
df = df.fillna(value='BLANK')
record_sum = len(df)

# %% [markdown]
# Review column blank counts and percentages

# %%
blank_counts = (df == "BLANK").sum()
with pd.option_context('display.max_rows', None):
    print(blank_counts)
# Out:
# _STATE                  0
# FMONTH                  0
# IDATE                   0
# IMONTH                  0
# IDAY                    0
# IYEAR                   0
# DISPCODE                0
# SEQNO                   0
# _PSU                    0
# CTELENM1           349081
# PVTRESD1           349082
# COLGHOUS           445113
# STATERE1           349082
# CELPHON1           349080
# LADULT1            349082
# COLGSEX1           445111
# NUMADULT           349100
# LANDSEX1           401436
# NUMMEN             394702
# NUMWOMEN           394699
# RESPSLCT           392879
# SAFETIME            96051
# CTELNUM1            96051
# CELLFON5            96052
# CADULT1             96052
# CELLSEX1            96053
# PVTRESD3            96058
# CCLGHOUS           443807
# CSTATE1             96060
# LANDLINE            96061
# HHADULT             96061
# SEXVAR                  0
# GENHLTH                 3
# PHYSHLTH                5
# MENTHLTH                3
# POORHLTH           189386
# PRIMINSR                4
# PERSDOC3                2
# MEDCOST1                4
# CHECKUP1                3
# EXERANY2                2
# SLEPTIM1                3
# LASTDEN4             1363
# RMVTETH4             1363
# CVDINFR4                4
# CVDCRHD4                2
# CVDSTRK3                2
# ASTHMA3                 2
# ASTHNOW            378438
# CHCSCNC1                2
# CHCOCNC1                3
# CHCCOPD3                2
# ADDEPEV3                7
# CHCKDNY2                2
# HAVARTH4                3
# DIABETE4                3
# DIABAGE4           383973
# MARITAL                 8
# EDUCA                   5
# RENTHOM1                9
# NUMHHOL4           349083
# NUMPHON4           438189
# CPDEMO1C             2827
# VETERAN3             4173
# EMPLOY1              6196
# CHILDREN             9312
# INCOME3             12932
# PREGNANT           366114
# WEIGHT2             15901
# HEIGHT3             17055
# DEAF                18644
# BLIND               19855
# DECIDE              20986
# DIFFWALK            22155
# DIFFDRES            22879
# DIFFALON            23942
# HADMAM             223319
# HOWLONG            274020
# CERVSCRN           224318
# CRVCLCNC           309555
# CRVCLPAP           309745
# CRVCLHPV           309960
# HADHYST2           227453
# HADSIGM4           152413
# COLNSIGM           232309
# COLNTES1           237848
# SIGMTES1           413769
# LASTSIG4           441658
# COLNCNCR           154046
# VIRCOLO1           383265
# VCLNTES2           436153
# SMALSTOL           383456
# STOLTEST           395758
# STOOLDN2           383730
# BLDSTFIT           433738
# SDNATES1           433770
# SMOKE100            31777
# SMOKDAY2           281079
# USENOW3             32600
# ECIGNOW2            33579
# LCSFIRST           283417
# LCSLAST            324513
# LCSNUMCG           288992
# LCSCTSC1            38210
# LCSSCNCR           279557
# LCSCTWHN           413627
# ALCDAY4             40763
# AVEDRNK3           234769
# DRNK3GE5           235283
# MAXDRNKS           235721
# FLUSHOT7            43593
# FLSHTMY3           236258
# PNEUVAC4            44732
# TETANUS1            45383
# HIVTST7             46235
# HIVTSTD3           316269
# HIVRISK5            48461
# COVIDPOS            49235
# COVIDSMP           320933
# COVIDPRM           418417
# PDIABTS1           304884
# PREDIAB2           304910
# DIABTYPE           432532
# INSULIN1           432532
# CHKHEMO3           432532
# EYEEXAM1           432532
# DIABEYE1           432532
# DIABEDU1           432532
# FEETSORE           432532
# TOLDCFS            445132
# HAVECFS            445132
# WORKCFS            445132
# IMFVPLA3           436089
# HPVADVC4           437786
# HPVADSHT           443460
# SHINGLE2           430395
# COVIDVA1           292089
# COVIDNU1           320385
# COVIDFS1           321193
# COVIDSE1           328043
# COPDCOGH           437863
# COPDFLEM           437870
# COPDBRTH           437883
# COPDBTST           437900
# COPDSMOK           437917
# CNCRDIFF           421733
# CNCRAGE            422567
# CNCRTYP2           422588
# CSRVTRT3           427830
# CSRVDOC1           435325
# CSRVSUM            435349
# CSRVRTRN           435361
# CSRVINST           437882
# CSRVINSR           435384
# CSRVDEIN           435392
# CSRVCLIN           435403
# CSRVPAIN           428035
# CSRVCTL2           443591
# PSATEST1           437952
# PSATIME1           441186
# PCPSARS2           441196
# PSASUGST           440738
# PCSTALK1           438364
# CIMEMLOS           380457
# CDHOUSE            437679
# CDASSIST           437701
# CDHELP             443199
# CDSOCIAL           437717
# CDDISCUS           437732
# CAREGIV1           346622
# CRGVREL4           425498
# CRGVLNG1           425549
# CRGVHRS1           425599
# CRGVPRB3           425660
# CRGVALZD           427832
# CRGVPER1           425732
# CRGVHOU1           425772
# CRGVEXPT           366598
# ACEDEPRS           396846
# ACEDRINK           396901
# ACEDRUGS           396912
# ACEPRISN           396938
# ACEDIVRC           396960
# ACEPUNCH           397003
# ACEHURT1           397055
# ACESWEAR           397103
# ACETOUCH           397160
# ACETTHEM           397196
# ACEHVSEX           397256
# ACEADSAF           397311
# ACEADNED           397375
# LSATISFY           190644
# EMTSUPRT           190991
# SDHISOLT           191342
# SDHEMPLY           191617
# FOODSTMP           191893
# SDHFOOD1           192303
# SDHBILLS           192610
# SDHUTILS           192853
# SDHTRNSP           193189
# SDHSTRE1           193921
# MARIJAN1           350213
# MARJSMOK           433622
# MARJEAT            433628
# MARJVAPE           433629
# MARJDAB            433637
# MARJOTHR           433645
# USEMRJN4           440126
# LASTSMK2           397723
# STOPSMK2           426243
# MENTCIGS           440138
# MENTECIG           442968
# HEATTBCO           430103
# ASBIALCH           384190
# ASBIDRNK           384292
# ASBIBING           384404
# ASBIADVC           385687
# ASBIRDUC           398512
# FIREARM5           405332
# GUNLOAD            431307
# LOADULK2           441077
# RCSGEND1           386144
# RCSXBRTH           441669
# RCSRLTN2           386658
# CASTHDX2           394471
# CASTHNO2           439804
# BIRTHSEX           365705
# SOMALE             321100
# SOFEMALE           305502
# TRNSGNDR           181571
# HADSEX             425256
# PFPPRVN4           430451
# TYPCNTR9           433762
# BRTHCNT4           433791
# WHEREGET           435358
# NOBCUSE8           441970
# BCPREFER           430605
# RRCLASS3           283394
# RRCOGNT2           283788
# RRTREAT            284167
# RRATWRK2           362095
# RRHCARE4           284624
# RRPHYSM2           284942
# QSTVER                  0
# QSTLANG                 0
# _METSTAT             9408
# _URBSTAT             9408
# MSCODE             351246
# _STSTR                  0
# _STRWT                  0
# _RAWRAKE                0
# _WT2RAKE                0
# _IMPRACE                0
# _CHISPNC           120823
# _CRACE2            384286
# _CPRACE2           385142
# CAGEG              394956
# _CLLCPWT           385986
# _DUALUSE                0
# _DUALCOR           287103
# _LLCPWT2                0
# _LLCPWT                 0
# _RFHLTH                 0
# _PHYS14D                0
# _MENT14D                0
# _HLTHPLN                0
# _HCVU652                0
# _TOTINDA                0
# _EXTETH3                0
# _ALTETH3           276713
# _DENVST3                4
# _MICHD               5021
# _LTASTH1                0
# _CASTHM1                0
# _ASTHMS1                0
# _DRDXAR2             2633
# _PRACE2                13
# _MRACE2                11
# _HISPANC                0
# _RACE1                  2
# _RACEG22                2
# _RACEGR4                2
# _RACEPR1                0
# _SEX                    0
# _AGEG5YR                0
# _AGE65YR                0
# _AGE80                  0
# _AGE_G                  0
# HTIN4               32476
# HTM4                28652
# WTKG3               42078
# _BMI5               48806
# _BMI5CAT            48806
# _RFBMI5                 0
# _CHLDCNT                1
# _EDUCAG                 0
# _INCOMG1                0
# _RFMAM22           263892
# _MAM5023           342456
# _HADCOLN           159803
# _CLNSCP1           223180
# _HADSIGM           159803
# _SGMSCP1           222919
# _SGMS101           222919
# _RFBLDS5           224909
# _STOLDN1           225325
# _VIRCOL1           225518
# _SBONTI1           229733
# _CRCREC2           223041
# _SMOKER3                0
# _RFSMOK3                0
# _CURECI2                0
# _YRSSMOK           297528
# _PACKDAY           294885
# _PACKYRS           302267
# _YRSQUIT           338802
# _SMOKGRP            35462
# _LCSREC            393679
# DRNKANY6                0
# DROCDY4_                4
# _RFBING6                0
# _DRNKWK2                0
# _RFDRHV8                0
# _FLSHOT7           276713
# _PNEUMO3           276713
# _AIDTST4            46235
# non_blank_count         0
# non_blank_perc          0
# dtype: int64

# %%
blank_perc = blank_counts / record_sum * 100
with pd.option_context('display.max_rows', None):
    print(blank_perc)
# Out:
# _STATE               0.000000
# FMONTH               0.000000
# IDATE                0.000000
# IMONTH               0.000000
# IDAY                 0.000000
# IYEAR                0.000000
# DISPCODE             0.000000
# SEQNO                0.000000
# _PSU                 0.000000
# CTELENM1            78.421906
# PVTRESD1            78.422131
# COLGHOUS            99.995732
# STATERE1            78.422131
# CELPHON1            78.421682
# LADULT1             78.422131
# COLGSEX1            99.995282
# NUMADULT            78.426175
# LANDSEX1            90.183586
# NUMMEN              88.670776
# NUMWOMEN            88.670102
# RESPSLCT            88.261235
# SAFETIME            21.578094
# CTELNUM1            21.578094
# CELLFON5            21.578318
# CADULT1             21.578318
# CELLSEX1            21.578543
# PVTRESD3            21.579666
# CCLGHOUS            99.702335
# CSTATE1             21.580116
# LANDLINE            21.580340
# HHADULT             21.580340
# SEXVAR               0.000000
# GENHLTH              0.000674
# PHYSHLTH             0.001123
# MENTHLTH             0.000674
# POORHLTH            42.546031
# PRIMINSR             0.000899
# PERSDOC3             0.000449
# MEDCOST1             0.000899
# CHECKUP1             0.000674
# EXERANY2             0.000449
# SLEPTIM1             0.000674
# LASTDEN4             0.306201
# RMVTETH4             0.306201
# CVDINFR4             0.000899
# CVDCRHD4             0.000449
# CVDSTRK3             0.000449
# ASTHMA3              0.000449
# ASTHNOW             85.017029
# CHCSCNC1             0.000449
# CHCOCNC1             0.000674
# CHCCOPD3             0.000449
# ADDEPEV3             0.001573
# CHCKDNY2             0.000449
# HAVARTH4             0.000674
# DIABETE4             0.000674
# DIABAGE4            86.260480
# MARITAL              0.001797
# EDUCA                0.001123
# RENTHOM1             0.002022
# NUMHHOL4            78.422356
# NUMPHON4            98.440238
# CPDEMO1C             0.635093
# VETERAN3             0.937475
# EMPLOY1              1.391947
# CHILDREN             2.091964
# INCOME3              2.905206
# PREGNANT            82.248412
# WEIGHT2              3.572199
# HEIGHT3              3.831448
# DEAF                 4.188421
# BLIND                4.460475
# DECIDE               4.714557
# DIFFWALK             4.977175
# DIFFDRES             5.139824
# DIFFALON             5.378629
# HADMAM              50.169163
# HOWLONG             61.559268
# CERVSCRN            50.393591
# CRVCLCNC            69.542293
# CRVCLPAP            69.584977
# CRVCLHPV            69.633277
# HADHYST2            51.097877
# HADSIGM4            34.239956
# COLNSIGM            52.188789
# COLNTES1            53.433139
# SIGMTES1            92.954225
# LASTSIG4            99.219557
# COLNCNCR            34.606813
# VIRCOLO1            86.101426
# VCLNTES2            97.982846
# SMALSTOL            86.144335
# STOLTEST            88.908009
# STOOLDN2            86.205889
# BLDSTFIT            97.440310
# SDNATES1            97.447499
# SMOKE100             7.138781
# SMOKDAY2            63.145090
# USENOW3              7.323670
# ECIGNOW2             7.543605
# LCSFIRST            63.670327
# LCSLAST             72.902645
# LCSNUMCG            64.922764
# LCSCTSC1             8.583971
# LCSSCNCR            62.803168
# LCSCTWHN            92.922324
# ALCDAY4              9.157508
# AVEDRNK3            52.741434
# DRNK3GE5            52.856905
# MAXDRNKS            52.955303
# FLUSHOT7             9.793275
# FLSHTMY3            53.075942
# PNEUVAC4            10.049154
# TETANUS1            10.195403
# HIVTST7             10.386807
# HIVTSTD3            71.050610
# HIVRISK5            10.886883
# COVIDPOS            11.060764
# COVIDSMP            72.098389
# COVIDPRM            93.998409
# PDIABTS1            68.492941
# PREDIAB2            68.498782
# DIABTYPE            97.169379
# INSULIN1            97.169379
# CHKHEMO3            97.169379
# EYEEXAM1            97.169379
# DIABEYE1            97.169379
# DIABEDU1            97.169379
# FEETSORE            97.169379
# TOLDCFS            100.000000
# HAVECFS            100.000000
# WORKCFS            100.000000
# IMFVPLA3            97.968468
# HPVADVC4            98.349703
# HPVADSHT            99.624381
# SHINGLE2            96.689297
# COVIDVA1            65.618513
# COVIDNU1            71.975279
# COVIDFS1            72.156798
# COVIDSE1            73.695668
# COPDCOGH            98.367001
# COPDFLEM            98.368574
# COPDBRTH            98.371494
# COPDBTST            98.375313
# COPDSMOK            98.379132
# CNCRDIFF            94.743357
# CNCRAGE             94.930717
# CNCRTYP2            94.935435
# CSRVTRT3            96.113063
# CSRVDOC1            97.796833
# CSRVSUM             97.802225
# CSRVRTRN            97.804921
# CSRVINST            98.371270
# CSRVINSR            97.810088
# CSRVDEIN            97.811885
# CSRVCLIN            97.814356
# CSRVPAIN            96.159117
# CSRVCTL2            99.653811
# PSATEST1            98.386995
# PSATIME1            99.113521
# PCPSARS2            99.115768
# PSASUGST            99.012877
# PCSTALK1            98.479552
# CIMEMLOS            85.470602
# CDHOUSE             98.325665
# CDASSIST            98.330608
# CDHELP              99.565747
# CDSOCIAL            98.334202
# CDDISCUS            98.337572
# CAREGIV1            77.869486
# CRGVREL4            95.589174
# CRGVLNG1            95.600631
# CRGVHRS1            95.611863
# CRGVPRB3            95.625567
# CRGVALZD            96.113512
# CRGVPER1            95.641742
# CRGVHOU1            95.650728
# CRGVEXPT            82.357143
# ACEDEPRS            89.152431
# ACEDRINK            89.164787
# ACEDRUGS            89.167258
# ACEPRISN            89.173099
# ACEDIVRC            89.178042
# ACEPUNCH            89.187702
# ACEHURT1            89.199384
# ACESWEAR            89.210167
# ACETOUCH            89.222972
# ACETTHEM            89.231060
# ACEHVSEX            89.244539
# ACEADSAF            89.256895
# ACEADNED            89.271272
# LSATISFY            42.828644
# EMTSUPRT            42.906598
# SDHISOLT            42.985452
# SDHEMPLY            43.047231
# FOODSTMP            43.109235
# SDHFOOD1            43.201343
# SDHBILLS            43.270311
# SDHUTILS            43.324901
# SDHTRNSP            43.400385
# SDHSTRE1            43.564830
# MARIJAN1            78.676213
# MARJSMOK            97.414250
# MARJEAT             97.415598
# MARJVAPE            97.415823
# MARJDAB             97.417620
# MARJOTHR            97.419417
# USEMRJN4            98.875390
# LASTSMK2            89.349451
# STOPSMK2            95.756540
# MENTCIGS            98.878086
# MENTECIG            99.513852
# HEATTBCO            96.623698
# ASBIALCH            86.309230
# ASBIDRNK            86.332144
# ASBIBING            86.357305
# ASBIADVC            86.645534
# ASBIRDUC            89.526702
# FIREARM5            91.058832
# GUNLOAD             96.894180
# LOADULK2            99.089034
# RCSGEND1            86.748201
# RCSXBRTH            99.222029
# RCSRLTN2            86.863672
# CASTHDX2            88.618882
# CASTHNO2            98.803052
# BIRTHSEX            82.156529
# SOMALE              72.135906
# SOFEMALE            68.631777
# TRNSGNDR            40.790372
# HADSEX              95.534808
# PFPPRVN4            96.701877
# TYPCNTR9            97.445701
# BRTHCNT4            97.452216
# WHEREGET            97.804247
# NOBCUSE8            99.289649
# BCPREFER            96.736474
# RRCLASS3            63.665160
# RRCOGNT2            63.753673
# RRTREAT             63.838816
# RRATWRK2            81.345533
# RRHCARE4            63.941483
# RRPHYSM2            64.012922
# QSTVER               0.000000
# QSTLANG              0.000000
# _METSTAT             2.113530
# _URBSTAT             2.113530
# MSCODE              78.908279
# _STSTR               0.000000
# _STRWT               0.000000
# _RAWRAKE             0.000000
# _WT2RAKE             0.000000
# _IMPRACE             0.000000
# _CHISPNC            27.143184
# _CRACE2             86.330796
# _CPRACE2            86.523099
# CAGEG               88.727838
# _CLLCPWT            86.712705
# _DUALUSE             0.000000
# _DUALCOR            64.498396
# _LLCPWT2             0.000000
# _LLCPWT              0.000000
# _RFHLTH              0.000000
# _PHYS14D             0.000000
# _MENT14D             0.000000
# _HLTHPLN             0.000000
# _HCVU652             0.000000
# _TOTINDA             0.000000
# _EXTETH3             0.000000
# _ALTETH3            62.164257
# _DENVST3             0.000899
# _MICHD               1.127980
# _LTASTH1             0.000000
# _CASTHM1             0.000000
# _ASTHMS1             0.000000
# _DRDXAR2             0.591510
# _PRACE2              0.002920
# _MRACE2              0.002471
# _HISPANC             0.000000
# _RACE1               0.000449
# _RACEG22             0.000449
# _RACEGR4             0.000449
# _RACEPR1             0.000000
# _SEX                 0.000000
# _AGEG5YR             0.000000
# _AGE65YR             0.000000
# _AGE80               0.000000
# _AGE_G               0.000000
# HTIN4                7.295813
# HTM4                 6.436742
# WTKG3                9.452926
# _BMI5               10.964388
# _BMI5CAT            10.964388
# _RFBMI5              0.000000
# _CHLDCNT             0.000225
# _EDUCAG              0.000000
# _INCOMG1             0.000000
# _RFMAM22            59.283988
# _MAM5023            76.933584
# _HADCOLN            35.900137
# _CLNSCP1            50.137937
# _HADSIGM            35.900137
# _SGMSCP1            50.079302
# _SGMS101            50.079302
# _RFBLDS5            50.526361
# _STOLDN1            50.619816
# _VIRCOL1            50.663174
# _SBONTI1            51.610084
# _CRCREC2            50.106710
# _SMOKER3             0.000000
# _RFSMOK3             0.000000
# _CURECI2             0.000000
# _YRSSMOK            66.840398
# _PACKDAY            66.246641
# _PACKYRS            67.905026
# _YRSQUIT            76.112704
# _SMOKGRP             7.966626
# _LCSREC             88.440957
# DRNKANY6             0.000000
# DROCDY4_             0.000899
# _RFBING6             0.000000
# _DRNKWK2             0.000000
# _RFDRHV8             0.000000
# _FLSHOT7            62.164257
# _PNEUMO3            62.164257
# _AIDTST4            10.386807
# non_blank_count      0.000000
# non_blank_perc       0.000000
# dtype: float64

# %% [markdown]
# Map columns and values to friendly values.

# %%
def process_variable(var, values_map):
    if isinstance(var, int):
        result = str(var)
    elif isinstance(var, float):
        result = str(int(var))
    else:
        result = var

    if result in values_map and values_map[result].strip() != '':
        result = f"{result} - {values_map[result]}"
    
    return result.strip()

# %%
new_column_names = []
for column_name in df.columns:
    if column_name in data_element_details and 'Label' in data_element_details[column_name]:
        new_column_names.append(data_element_details[column_name]['Label'])
        values_map = {key: value['Value Label'] for key, value in data_element_details[column_name]['Valid Values'].items()}
        df[column_name] = df[column_name].map(lambda x: process_variable(x, values_map))
    else:
        new_column_names.append(column_name)
    
df.columns = new_column_names

# %%
df
# Out:
#             State FIPS Code     File Month Interview Date Interview Month  \
# 0               1 - Alabama    1 - January        2032022    2 - February
# 1               1 - Alabama    1 - January        2042022    2 - February
# 2               1 - Alabama    1 - January        2022022    2 - February
# 3               1 - Alabama    1 - January        2032022    2 - February
# 4               1 - Alabama    1 - January        2022022    2 - February
# ...                     ...            ...            ...             ...
# 445127  78 - Virgin Islands  11 - November       12192022   12 - December
# 445128  78 - Virgin Islands  11 - November       12212022   12 - December
# 445129  78 - Virgin Islands  11 - November       11292022   11 - November
# 445130  78 - Virgin Islands  11 - November       12082022   12 - December
# 445131  78 - Virgin Islands  11 - November       12142022   12 - December
#
#        Interview Day Interview Year           Final Disposition  \
# 0                  3           2022  1100 - Completed Interview
# 1                  4           2022  1100 - Completed Interview
# 2                  2           2022  1100 - Completed Interview
# 3                  3           2022  1100 - Completed Interview
# 4                  2           2022  1100 - Completed Interview
# ...              ...            ...                         ...
# 445127            19           2022  1100 - Completed Interview
# 445128            21           2022  1100 - Completed Interview
# 445129            29           2022  1100 - Completed Interview
# 445130             8           2022  1100 - Completed Interview
# 445131            14           2022  1100 - Completed Interview
#
#        Annual Sequence Number Primary Sampling Unit  \
# 0                  2022000001            2022000001
# 1                  2022000002            2022000002
# 2                  2022000003            2022000003
# 3                  2022000004            2022000004
# 4                  2022000005            2022000005
# ...                       ...                   ...
# 445127             2022001527            2022001527
# 445128             2022001528            2022001528
# 445129             2022001529            2022001529
# 445130             2022001530            2022001530
# 445131             2022001531            2022001531
#
#             Correct telephone number?  ...  \
# 0       1 - YesGo to LL.02, PVTRESD1  ...
# 1       1 - YesGo to LL.02, PVTRESD1  ...
# 2       1 - YesGo to LL.02, PVTRESD1  ...
# 3       1 - YesGo to LL.02, PVTRESD1  ...
# 4       1 - YesGo to LL.02, PVTRESD1  ...
# ...                               ...  ...
# 445127                BLANK - Missing  ...
# 445128                BLANK - Missing  ...
# 445129                BLANK - Missing  ...
# 445130                BLANK - Missing  ...
# 445131                BLANK - Missing  ...
#
#        Drink any alcoholic beverages in past 30 days  \
# 0                                             2 - No
# 1                                             2 - No
# 2                                             2 - No
# 3                                             2 - No
# 4                                            1 - Yes
# ...                                              ...
# 445127                       7 - Dont know/Not Sure
# 445128                                        2 - No
# 445129                       7 - Dont know/Not Sure
# 445130                                        2 - No
# 445131                                       1 - Yes
#
#                     Computed drink-occasions-per-day  \
# 0                     0 - No Drink-Occasions per day
# 1                     0 - No Drink-Occasions per day
# 2                     0 - No Drink-Occasions per day
# 3                     0 - No Drink-Occasions per day
# 4                                                 10
# ...                                              ...
# 445127  900 - Dont know/Not Sure Or Refused/Missing
# 445128                0 - No Drink-Occasions per day
# 445129  900 - Dont know/Not Sure Or Refused/Missing
# 445130                0 - No Drink-Occasions per day
# 445131                                            50
#
#        Binge Drinking Calculated Variable  \
# 0                                  1 - No
# 1                                  1 - No
# 2                                  1 - No
# 3                                  1 - No
# 4                                  1 - No
# ...                                   ...
# 445127     9 - Dont know/Refused/Missing
# 445128                             1 - No
# 445129     9 - Dont know/Refused/Missing
# 445130                             1 - No
# 445131                            2 - Yes
#
#        Computed number of drinks of alcohol beverages per week  \
# 0                                       0 - Did not drink
# 1                                       0 - Did not drink
# 2                                       0 - Did not drink
# 3                                       0 - Did not drink
# 4                                                     140
# ...                                                   ...
# 445127        99900 - Dont know/Not sure/Refused/Missing
# 445128                                  0 - Did not drink
# 445129        99900 - Dont know/Not sure/Refused/Missing
# 445130                                  0 - Did not drink
# 445131        99900 - Dont know/Not sure/Refused/Missing
#
#        Heavy Alcohol Consumption  Calculated Variable  \
# 0                                              1 - No
# 1                                              1 - No
# 2                                              1 - No
# 3                                              1 - No
# 4                                              1 - No
# ...                                               ...
# 445127                 9 - Dont know/Refused/Missing
# 445128                                         1 - No
# 445129                 9 - Dont know/Refused/Missing
# 445130                                         1 - No
# 445131                 9 - Dont know/Refused/Missing
#
#                       Flu Shot Calculated Variable  \
# 0                                          1 - Yes
# 1                                           2 - No
# 2                                 BLANK - Age < 65
# 3       9 - Dont know/Not Sure Or Refused/Missing
# 4                                 BLANK - Age < 65
# ...                                            ...
# 445127                            BLANK - Age < 65
# 445128                            BLANK - Age < 65
# 445129                                      2 - No
# 445130                                     1 - Yes
# 445131                            BLANK - Age < 65
#
#          Pneumonia Vaccination Calculated Variable  \
# 0                                           2 - No
# 1                                           2 - No
# 2                                 BLANK - Age < 65
# 3       9 - Dont know/Not Sure Or Refused/Missing
# 4                                 BLANK - Age < 65
# ...                                            ...
# 445127                            BLANK - Age < 65
# 445128                            BLANK - Age < 65
# 445129                                      2 - No
# 445130                                     1 - Yes
# 445131                            BLANK - Age < 65
#
#        Ever been tested for HIV calculated variable non_blank_count  \
# 0                                            2 - No             177
# 1                                            2 - No             175
# 2                                            2 - No             171
# 3                                            2 - No             162
# 4                                            2 - No             176
# ...                                             ...             ...
# 445127                                      1 - Yes             177
# 445128                                      1 - Yes             160
# 445129                                       2 - No             169
# 445130                                      1 - Yes             165
# 445131                                       2 - No             173
#
#        non_blank_perc
# 0            0.558360
# 1            0.552050
# 2            0.539432
# 3            0.511041
# 4            0.555205
# ...               ...
# 445127       0.558360
# 445128       0.504732
# 445129       0.533123
# 445130       0.520505
# 445131       0.545741
#
# [445132 rows x 328 columns]

# %% [markdown]
# Export to CSV

# %%
df.to_csv('../data/processed.csv')
